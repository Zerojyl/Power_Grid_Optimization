# %%
from make_dataset import make_dataset
import yaml

with open('../configs/power_forecasting/lstm_power_forecasting.yaml') as file:
    config = yaml.safe_load(file)

print(config['data_config'])
my_dataset1 = make_dataset(data_path=config['data_config']['data1']['data_path'],
                          normalization=config['data_config']['normalization'], 
                          previous_step=config['data_config']['previous_step'], 
                          previous_drop=config['data_config']['previous_drop'],
                          forecast_step=config['data_config']['forecast_step'],
                          forecast_drop=config['data_config']['forecast_drop'], 
                          dropnan=True)


df = my_dataset1.dataframe
y = df[config['data_config']['target_features']]
X = df.drop(config['data_config']['target_features'], axis=1)
# Out:
# {'data1': {'data_path': 'Data/power_data/merged_power_data1.csv', 'dataset_save_path': 'Data/power_data/dataset1.pkl'}, 'data2': {'data_path': './Data/power_data/merged_power_data2.csv', 'dataset_save_path': './Data/power_data/dataset2.pkl'}, 'data3': {'data_path': './Data/power_data/merged_power_data3.csv', 'dataset_save_path': './Data/power_data/dataset3.pkl'}, 'data4': {'data_path': './Data/power_data/merged_power_data4.csv', 'dataset_save_path': './Data/power_data/dataset4.pkl'}, 'normalization': 'standard', 'previous_drop': ['forcast_wind_speed_10m', 'forcast_wind_direction_10m', 'forcast_wind_speed_30m', 'forcast_wind_direction_30m', 'forcast_wind_speed_50m', 'forcast_wind_direction_50m', 'forcast_wind_speed_70m', 'forcast_wind_direction_70m', 'forcast_air_pressure', 'forcast_temperature', 'forcast_humidity'], 'forecast_drop': ['wind_speed_10m', 'wind_direction_10m', 'wind_speed_30m', 'wind_direction_30m', 'wind_speed_50m', 'wind_direction_50m', 'wind_speed_70m', 'wind_directio
# ...
